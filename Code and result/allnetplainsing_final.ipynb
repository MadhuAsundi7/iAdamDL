# %%
import os
import pandas as pd
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
from torchvision import models

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
class ImageDataset(Dataset):
    def __init__(self, csv_file, img_dir, transform=None, max_attempts=5):
        self.annotations = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.transform = transform
        self.max_attempts = max_attempts  # Limit attempts to avoid infinite loops

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, idx):
        attempts = 0
        while attempts < self.max_attempts:
            try:
                # Get image path
                img_name = os.path.join(self.img_dir, f"{int(self.annotations.iloc[idx]['imagefile']):06}.jpg")

                image = Image.open(img_name).convert("RGB")

                # Get label
                label = torch.tensor(int(self.annotations.iloc[idx]['ID']))

                # Apply transformation if available
                if self.transform:
                    image = self.transform(image)

                return image, label

            except FileNotFoundError:
                # Handle missing file and attempt to move to the next image
                print(f"File not found: {self.annotations.iloc[idx]['imagefile']}. Skipping...")
                idx = (idx + 1) % len(self.annotations)  # Move to the next image
                attempts += 1  # Count this as a failed attempt

        # If the loop exceeds max_attempts, raise an error
        raise RuntimeError(f"Exceeded maximum attempts to load valid images. Check your dataset.")

# %%
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    # transforms.ColorJitter(contrast=5, brightness=5),  # Adjust contrast and brightness
    # transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),  # Apply Gaussian blur
    transforms.ToTensor(),
    #transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3)), # Resize images to the size expected by ResNet

    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Standard normalization for ImageNet
])

# %%
import os
import csv
from torch.utils.data.sampler import SubsetRandomSampler
import numpy as np
# Mount Google Drive (if using Google Colab)
from google.colab import drive
drive.mount('/content/mydrive')

# Define the paths to the folders and CSV file
drive_path = '/content/mydrive/MyDrive/'  # Modify as needed
check_folder = os.path.join(drive_path, 'check')
plainsing_folder = os.path.join(drive_path, 'plainsing')
csv_file_path = os.path.join(check_folder, 'idplainsing_mapped.csv')

batch_size= 20
num_workers = 0

# Specify the root directory for images and the CSV file containing class labels and filenames
root_dir = '/content/mydrive/MyDrive/check/plainsing'  # Change this to your directory
csv_file = '/content/mydrive/MyDrive/check/idplainsing_mapped.csv'  # CSV file containing ids (labels) and image filenames

valid_size = 0.2

csv_file =csv_file_path  # Path to CSV with image file names and labels
img_dir = plainsing_folder  # Path to image folder
dataset = ImageDataset(csv_file, root_dir, transform=transform)

# Split dataset into validation and test sets
train_size = int(0.8 * len(dataset))  # 80% for training
test_size = len(dataset) - train_size  # 20% for testing
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
num_train = len(train_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
    num_workers=num_workers)
# Out:
# Drive already mounted at /content/mydrive; to attempt to forcibly remount, call drive.mount("/content/mydrive", force_remount=True).

# %%
num_classes = 47 # 107 unique tiger ids


# optimizer = torch.optim.Adam(model.parameters(), lr=0.2)
# criterion = nn.CrossEntropyLoss()
# if train_on_gpu:
#   model.cuda()

# %%
import torch
import torch.nn as nn

class iAdam(torch.optim.Optimizer):
    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8):
        # Initialize default values for learning rate, betas, and epsilon
        defaults = {'lr': lr, 'betas': betas, 'eps': eps}
        super(iAdam, self).__init__(params, defaults)

        # Initialize state for each parameter (e.g., for each weight)
        for group in self.param_groups:
            for p in group['params']:
                self.state[p] = {
                    'step': 0,  # Tracks the number of updates
                    'exp_avg': torch.zeros_like(p.data),  # Exponential moving average of gradients (m_w, m_b)
                    'exp_avg_sq': torch.zeros_like(p.data),  # Exponential moving average of squared gradients (v_w, v_b)
                }

    def step(self):
        # Loop over parameter groups
        for group in self.param_groups:
            lr = group['lr']  # Learning rate
            beta1, beta2 = group['betas']  # Betas for moving averages
            eps = group['eps']  # Small epsilon to prevent division by zero

            # Loop over each parameter in the group (e.g., weights, biases)
            for p in group['params']:
                if p.grad is None:
                    continue  # Skip parameters with no gradients

                # Get the state for this parameter
                state = self.state[p]

                # Update step count
                state['step'] += 1

                # Get the moving averages of gradients and squared gradients
                exp_avg = state['exp_avg']  # This is like m_w or m_b
                exp_avg_sq = state['exp_avg_sq']  # This is like v_w or v_b

                # Get the gradient
                grad = p.grad.data

                # Moment-shifted weights: w_shift = p - exp_avg (equivalent to m_w and m_b shifting)
                shifted_weight = p.data - exp_avg

                # Compute the gradient based on the shifted weight (i.e., moment-shifted gradient)
                # You can customize this part based on your gradient calculation logic
                shifted_grad = grad - exp_avg  # Moment-shifted gradient calculation (can be adjusted as needed)

                # Update the moving averages with the new gradients
                exp_avg.mul_(beta1).add_(shifted_grad, alpha=1 - beta1)  # m_w = beta1 * m_w + (1 - beta1) * dw_shifted
                exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)  # v_w = beta2 * v_w + (1 - beta2) * dw**2

                # Compute bias-corrected estimates for moving averages
                bias_correction1 = 1 - beta1 ** state['step']  # Bias correction for m_w
                bias_correction2 = 1 - beta2 ** state['step']  # Bias correction for v_w

                # Compute the step size and final parameter update
                step_size = lr / bias_correction1  # Corrected learning rate
                denom = exp_avg_sq.sqrt().div(bias_correction2).add_(eps)  # Adjust denominator with epsilon to avoid division by zero
                p.data.addcdiv_(exp_avg, denom, value=-step_size)  # Update weights using Adam formula

# %%
# # images, labels = next(iter(dataloader))
# # print(images.shape, labels.shap
# dataiter = iter(train_loader)
# data = next(dataiter)
# images, labels = data
# print(images.shape, labels.shape)

# %%
#with regularisation
class iAdam(torch.optim.Optimizer):
    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=0.1, lambda_func=lambda t: 1.0):
        defaults = {'lr': lr, 'betas': betas, 'eps': eps, 'weight_decay': weight_decay, 'lambda_func': lambda_func}
        super(iAdam, self).__init__(params, defaults)
        # Initialize state for each parameter
        for p in self.param_groups[0]['params']:
            self.state[p] = {
                'step': 0,
                'exp_avg': torch.zeros_like(p.data),
                'exp_avg_sq': torch.zeros_like(p.data),
            }

    def step(self):
        for group in self.param_groups:
            lr = group['lr']
            beta1, beta2 = group['betas']
            eps = group['eps']
            weight_decay = group['weight_decay']  # Fetch weight decay
            lambda_func = group['lambda_func']

            for p in group['params']:
                if p.grad is None:
                    continue

                state = self.state[p]
                state['step'] += 1
                exp_avg = state['exp_avg']
                exp_avg_sq = state['exp_avg_sq']

                # Calculate lambda_t and check for validity
                lambda_t = torch.tensor(lambda_func(state['step']), dtype=torch.float32)
                if torch.isnan(lambda_t) or torch.isinf(lambda_t):
                    lambda_t = torch.tensor(1.0)  # Default to 1.0 if invalid

                # Apply weight decay (L2 regularization)
                if weight_decay > 0:
                    p.grad.data.add_(weight_decay * p.data)

                # Compute the weight penalty
                weight_penalty = lambda_t * p.data * 0.000001

                # Compute the adjusted gradient
                grad = p.grad.data - exp_avg + weight_penalty
                exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
                exp_avg_sq.mul_(beta2).addcmul_(p.grad.data, p.grad.data, value=1 - beta2)

                # Compute bias-corrected averages
                bias_correction1 = 1 - beta1 ** state['step']
                bias_correction2 = 1 - beta2 ** state['step']

                # Compute the step size and denominator
                step_size = lr / bias_correction1
                denom = exp_avg_sq.sqrt().div(bias_correction2).add_(eps)

                # Update parameters
                p.data.addcdiv_(exp_avg, denom, value=-step_size)

                # Optionally apply gradient clipping before updating parameters
                torch.nn.utils.clip_grad_norm_([p], max_norm=1.0)

# %% [markdown]
# # **[ALEXNET Code training](https://)**

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pandas as pd
import matplotlib.pyplot as plt
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pre-trained AlexNet model
model = models.alexnet(pretrained=True)

# Freeze all layers except the final fully connected layer
for param in model.features.parameters():
    param.requires_grad = False  # Freeze feature extraction layers

# Modify the final fully connected layer for 28 classes
model.classifier[6] = nn.Linear(model.classifier[6].in_features, 47)

# Move the model to the GPU
model = model.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = iAdam(model.parameters(), lr=0.001)  # Adam optimizer

num_epochs = 20
train_loss_list = []  # To store training loss
val_loss_list = []    # To store validation loss
best_val_loss = float('inf')  # Initialize with infinity to track the best validation loss
best_model_path = "AlexNetbest_model.pth"  # File to store the best model

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()  # Clear gradients
        loss.backward()        # Backpropagation
        optimizer.step()       # Update weights

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append((epoch + 1, epoch_train_loss))  # Store epoch number and training loss
    print(f'Epoch {epoch+1} finished, Train Loss: {epoch_train_loss:.4f}')

    # Validation phase
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in valid_loader:  # Use your validation loader
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(valid_loader)
    val_loss_list.append((epoch + 1, epoch_val_loss))  # Store epoch number and validation loss
    print(f'Epoch {epoch+1} finished, Validation Loss: {epoch_val_loss:.4f}')

    # Save the model if it has the best validation loss so far
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)  # Save the model's state dictionary
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")

# Combine and save losses to a CSV file
loss_data = [(epoch, train_loss, val_loss) for (epoch, train_loss), (_, val_loss) in zip(train_loss_list, val_loss_list)]
df = pd.DataFrame(loss_data, columns=['Epoch', 'Train Loss', 'Validation Loss'])
df.to_csv('lossesAlexNet.csv', index=False)

print("Losses saved to 'lossesalex.csv'.")

# Plotting the losses
epochs = [epoch for epoch, _ in train_loss_list]
train_losses = [loss for _, loss in train_loss_list]
val_losses = [loss for _, loss in val_loss_list]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.savefig('loss_plotAlex.png')  # Save the plot as a PNG file
plt.show()  # Display the plot
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 finished, Train Loss: 3.4139
# Epoch 1 finished, Validation Loss: 1.7645
# Best model saved with validation loss: 1.7645
# Epoch 2 finished, Train Loss: 0.9563
# Epoch 2 finished, Validation Loss: 0.9345
# Best model saved with validation loss: 0.9345
# Epoch 3 finished, Train Loss: 0.4022
# Epoch 3 finished, Validation Loss: 0.8319
# Best model saved with validation loss: 0.8319
# Epoch 4 finished, Train Loss: 0.3054
# Epoch 4 finished, Validation Loss: 0.8799
# Epoch 5 finished, Train Loss: 0.4325
# Epoch 5 finished, Validation Loss: 0.8619
# Epoch 6 finished, Train Loss: 0.4134
# Epoch 6 finished, Validation Loss: 0.9839
# Epoch 7 finished, Train Loss: 0.5183
# Epoch 7 finished, Validation Loss: 1.3117
# Epoch 8 finished, Train Loss: 0.8340
# Epoch 8 finished, Validation Loss: 1.1129
# Epoch 9 finished, Train Loss: 0.8919
# Epoch 9 finished, Validation Loss: 1.2243
# Epoch 10 finished, Train Loss: 0.7630
# Epoch 10 finished, Validation Loss: 0.9098
# Epoch 11 finished, Train Loss: 0.7381
# Epoch 11 finished, Validation Loss: 1.3804
# Epoch 12 finished, Train Loss: 0.8027
# Epoch 12 finished, Validation Loss: 0.9944
# Epoch 13 finished, Train Loss: 0.8492
# Epoch 13 finished, Validation Loss: 1.4389
# Epoch 14 finished, Train Loss: 0.7812
# Epoch 14 finished, Validation Loss: 1.5670
# Epoch 15 finished, Train Loss: 0.8756
# Epoch 15 finished, Validation Loss: 1.1479
# Epoch 16 finished, Train Loss: 0.7857
# Epoch 16 finished, Validation Loss: 1.1120
# Epoch 17 finished, Train Loss: 0.8478
# Epoch 17 finished, Validation Loss: 1.3306
# Epoch 18 finished, Train Loss: 0.8100
# Epoch 18 finished, Validation Loss: 1.1287
# Epoch 19 finished, Train Loss: 0.8098
# Epoch 19 finished, Validation Loss: 1.3454
# Epoch 20 finished, Train Loss: 0.6922
# Epoch 20 finished, Validation Loss: 1.1272
# Losses saved to 'lossesalex.csv'.

# %% [markdown]
# # **AlexNet Testing**

# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score
from tqdm import tqdm

# Function to calculate mAP (mean Average Precision)
def calculate_map(all_labels, all_scores, num_classes):
    mAP_scores = []
    for c in range(num_classes):
        true_labels = (all_labels == c).astype(int)
        pred_scores = all_scores[:, c]  # Scores for class c

        # Handle case where there are no positive samples
        if true_labels.sum() == 0:
            mAP_scores.append(0.0)
            continue

        ap = average_precision_score(true_labels, pred_scores)
        mAP_scores.append(ap)

    mAP = np.mean(mAP_scores)
    return mAP

# Function to evaluate the model
def evaluate_model(model, test_loader, num_classes, model_path=None):
    # Load the best model if the path is provided
    if model_path is not None:
        print(f"Loading the best model from {model_path}")
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)

    model.eval()  # Set model to evaluation mode
    top1_correct = 0
    top5_correct = 0
    total = 0
    all_labels = []
    all_preds = []
    all_scores = []

    with torch.no_grad():
        for images, labels in tqdm(test_loader):
            images = images.to(device)  # Move images to the GPU
            labels = labels.to(device)  # Move labels to the GPU

            outputs = model(images)  # Forward pass

            # Get predicted class probabilities
            pred_scores = torch.softmax(outputs, dim=1)  # Shape: (batch_size, num_classes)

            # Get class predictions
            _, predicted = torch.max(outputs, 1)  # Shape: (batch_size,)

            # Top-1 accuracy
            top1_correct += (predicted == labels).sum().item()
            # Top-5 accuracy
            _, top5_pred = torch.topk(outputs, 5, dim=1)
            top5_correct += (top5_pred == labels.view(-1, 1).expand_as(top5_pred)).sum().item()

            total += labels.size(0)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
            all_scores.append(pred_scores.cpu().numpy())  # Append the scores

    # Calculate accuracies
    top1_accuracy = (top1_correct / total) * 100
    top5_accuracy = (top5_correct / total) * 100

    # Concatenate all predicted scores into a 2D array
    all_scores = np.concatenate(all_scores)  # Shape: (num_samples, num_classes)

    # Calculate mean Average Precision (mAP)
    mAP = calculate_map(np.array(all_labels), all_scores, num_classes)

    print(f'Top-1 Accuracy: {top1_accuracy:.4f}')
    print(f'Top-5 Accuracy: {top5_accuracy:.4f}')
    print(f'mAP: {mAP:.4f}')

    return {
        'Top-1 Accuracy': top1_accuracy,
        'Top-5 Accuracy': top5_accuracy,
        'mAP': mAP,
    }

# Example usage
best_model_path = 'AlexNetbest_model.pth'  # Path where the best model is saved
results = evaluate_model(model, test_loader, num_classes=28, model_path=best_model_path)

# Print evaluation results
for metric, value in results.items():
    print(f'{metric}: {value:.4f}')
# Out:
# Loading the best model from AlexNetbest_model.pth
# <ipython-input-32-60b52088d642>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 100%|██████████| 8/8 [00:01<00:00,  5.50it/s]
# Top-1 Accuracy: 77.3050
# Top-5 Accuracy: 97.8723
# mAP: 0.8021
# Top-1 Accuracy: 77.3050
# Top-5 Accuracy: 97.8723
# mAP: 0.8021

# %% [markdown]
# ## **ResNet18 Training**

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pandas as pd
import matplotlib.pyplot as plt
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pre-trained ResNet model
model = models.resnet18(pretrained=True)  # You can also use resnet50 or resnet101, etc.

# Freeze all convolutional layers (i.e., feature extractor)
for param in model.parameters():
    param.requires_grad = False

# Modify the final fully connected layer for 28 output classes
num_classes = 47
model.fc = nn.Linear(model.fc.in_features, num_classes)

# Move the model to the GPU
model = model.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = iAdam(model.parameters(), lr=0.001)  # Adam optimizer

num_epochs = 20
train_loss_list = []  # To store training loss
val_loss_list = []    # To store validation loss
best_val_loss = float('inf')  # Initialize with infinity to track the best validation loss
best_model_path = "ResNetbest_model.pth"  # File to store the best model

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()  # Clear gradients
        loss.backward()        # Backpropagation
        optimizer.step()       # Update weights

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append((epoch + 1, epoch_train_loss))  # Store epoch number and training loss
    print(f'Epoch {epoch+1} finished, Train Loss: {epoch_train_loss:.4f}')

    # Validation phase
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in valid_loader:  # Use your validation loader
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(valid_loader)
    val_loss_list.append((epoch + 1, epoch_val_loss))  # Store epoch number and validation loss
    print(f'Epoch {epoch+1} finished, Validation Loss: {epoch_val_loss:.4f}')

    # Save the model if it has the best validation loss so far
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)  # Save the model's state dictionary
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")

# Combine and save losses to a CSV file
loss_data = [(epoch, train_loss, val_loss) for (epoch, train_loss), (_, val_loss) in zip(train_loss_list, val_loss_list)]
df = pd.DataFrame(loss_data, columns=['Epoch', 'Train Loss', 'Validation Loss'])
df.to_csv('lossesResNet.csv', index=False)

print("Losses saved to 'losses.csv'.")

# Plotting the losses
epochs = [epoch for epoch, _ in train_loss_list]
train_losses = [loss for _, loss in train_loss_list]
val_losses = [loss for _, loss in val_loss_list]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.savefig('loss_plotResnet.png')  # Save the plot as a PNG file
plt.show()  # Display the plot
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 finished, Train Loss: 4.3182
# Epoch 1 finished, Validation Loss: 4.1430
# Best model saved with validation loss: 4.1430
# Epoch 2 finished, Train Loss: 4.0067
# Epoch 2 finished, Validation Loss: 3.8776
# Best model saved with validation loss: 3.8776
# Epoch 3 finished, Train Loss: 3.8303
# Epoch 3 finished, Validation Loss: 3.7358
# Best model saved with validation loss: 3.7358
# Epoch 4 finished, Train Loss: 3.5921
# Epoch 4 finished, Validation Loss: 3.6184
# Best model saved with validation loss: 3.6184
# Epoch 5 finished, Train Loss: 3.3660
# Epoch 5 finished, Validation Loss: 3.4450
# Best model saved with validation loss: 3.4450
# Epoch 6 finished, Train Loss: 3.2089
# Epoch 6 finished, Validation Loss: 3.2850
# Best model saved with validation loss: 3.2850
# Epoch 7 finished, Train Loss: 2.9603
# Epoch 7 finished, Validation Loss: 3.1091
# Best model saved with validation loss: 3.1091
# Epoch 8 finished, Train Loss: 2.7787
# Epoch 8 finished, Validation Loss: 2.9396
# Best model saved with validation loss: 2.9396
# Epoch 9 finished, Train Loss: 2.5577
# Epoch 9 finished, Validation Loss: 2.7859
# Best model saved with validation loss: 2.7859
# Epoch 10 finished, Train Loss: 2.3905
# Epoch 10 finished, Validation Loss: 2.5792
# Best model saved with validation loss: 2.5792
# Epoch 11 finished, Train Loss: 2.1577
# Epoch 11 finished, Validation Loss: 2.4329
# Best model saved with validation loss: 2.4329
# Epoch 12 finished, Train Loss: 1.9968
# Epoch 12 finished, Validation Loss: 2.2723
# Best model saved with validation loss: 2.2723
# Epoch 13 finished, Train Loss: 1.8657
# Epoch 13 finished, Validation Loss: 2.2005
# Best model saved with validation loss: 2.2005
# Epoch 14 finished, Train Loss: 1.6752
# Epoch 14 finished, Validation Loss: 2.0975
# Best model saved with validation loss: 2.0975
# Epoch 15 finished, Train Loss: 1.6448
# Epoch 15 finished, Validation Loss: 2.0335
# Best model saved with validation loss: 2.0335
# Epoch 16 finished, Train Loss: 1.4643
# Epoch 16 finished, Validation Loss: 1.8983
# Best model saved with validation loss: 1.8983
# Epoch 17 finished, Train Loss: 1.3540
# Epoch 17 finished, Validation Loss: 1.8034
# Best model saved with validation loss: 1.8034
# Epoch 18 finished, Train Loss: 1.2981
# Epoch 18 finished, Validation Loss: 1.7334
# Best model saved with validation loss: 1.7334
# Epoch 19 finished, Train Loss: 1.1880
# Epoch 19 finished, Validation Loss: 1.6599
# Best model saved with validation loss: 1.6599
# Epoch 20 finished, Train Loss: 1.1076
# Epoch 20 finished, Validation Loss: 1.5501
# Best model saved with validation loss: 1.5501
# Losses saved to 'losses.csv'.

# %% [markdown]
# # **ResNet Testing**

# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score
from tqdm import tqdm

# Function to calculate mAP (mean Average Precision)
def calculate_map(all_labels, all_scores, num_classes):
    mAP_scores = []
    for c in range(num_classes):
        true_labels = (all_labels == c).astype(int)
        pred_scores = all_scores[:, c]  # Scores for class c

        # Handle case where there are no positive samples
        if true_labels.sum() == 0:
            mAP_scores.append(0.0)
            continue

        ap = average_precision_score(true_labels, pred_scores)
        mAP_scores.append(ap)

    mAP = np.mean(mAP_scores)
    return mAP

# Function to evaluate the model
def evaluate_model(model, test_loader, num_classes, model_path=None):
    # Load the best model if the path is provided
    if model_path is not None:
        print(f"Loading the best model from {model_path}")
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)

    model.eval()  # Set model to evaluation mode
    top1_correct = 0
    top5_correct = 0
    total = 0
    all_labels = []
    all_preds = []
    all_scores = []

    with torch.no_grad():
        for images, labels in tqdm(test_loader):
            images = images.to(device)  # Move images to the GPU
            labels = labels.to(device)  # Move labels to the GPU

            outputs = model(images)  # Forward pass

            # Get predicted class probabilities
            pred_scores = torch.softmax(outputs, dim=1)  # Shape: (batch_size, num_classes)

            # Get class predictions
            _, predicted = torch.max(outputs, 1)  # Shape: (batch_size,)

            # Top-1 accuracy
            top1_correct += (predicted == labels).sum().item()
            # Top-5 accuracy
            _, top5_pred = torch.topk(outputs, 5, dim=1)
            top5_correct += (top5_pred == labels.view(-1, 1).expand_as(top5_pred)).sum().item()

            total += labels.size(0)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
            all_scores.append(pred_scores.cpu().numpy())  # Append the scores

    # Calculate accuracies
    top1_accuracy = (top1_correct / total) * 100
    top5_accuracy = (top5_correct / total) * 100

    # Concatenate all predicted scores into a 2D array
    all_scores = np.concatenate(all_scores)  # Shape: (num_samples, num_classes)

    # Calculate mean Average Precision (mAP)
    mAP = calculate_map(np.array(all_labels), all_scores, num_classes)

    print(f'Top-1 Accuracy: {top1_accuracy:.4f}')
    print(f'Top-5 Accuracy: {top5_accuracy:.4f}')
    print(f'mAP: {mAP:.4f}')

    return {
        'Top-1 Accuracy': top1_accuracy,
        'Top-5 Accuracy': top5_accuracy,
        'mAP': mAP,
    }

# Example usage
best_model_path = 'ResNetbest_model.pth'  # Path where the best model is saved
results = evaluate_model(model, test_loader, num_classes=47, model_path=best_model_path)

# Print evaluation results
for metric, value in results.items():
    print(f'{metric}: {value:.4f}')
# Out:
# <ipython-input-34-1beb32cf02e7>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Loading the best model from ResNetbest_model.pth
# 100%|██████████| 8/8 [00:01<00:00,  5.53it/s]
# Top-1 Accuracy: 76.5957
# Top-5 Accuracy: 92.9078
# mAP: 0.7331
# Top-1 Accuracy: 76.5957
# Top-5 Accuracy: 92.9078
# mAP: 0.7331

# %% [markdown]
# # **VGGNet16 Training**

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pandas as pd
import matplotlib.pyplot as plt
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pre-trained VGG16 model
model = models.vgg16(pretrained=True)  # You can also use vgg19

# Freeze all layers except the classifier (fully connected layers)
for param in model.features.parameters():  # Freeze feature extractor (convolutional layers)
    param.requires_grad = False

# Modify the final classifier layer for 28 output classes
num_classes = 47
model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)

# Move the model to the GPU
model = model.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = iAdam(model.parameters(), lr=0.001)  # Adam optimizer

num_epochs = 20
train_loss_list = []  # To store training loss
val_loss_list = []    # To store validation loss
best_val_loss = float('inf')  # Initialize with infinity to track the best validation loss
best_model_path = "VGGNetbest_model.pth"  # File to store the best model

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()  # Clear gradients
        loss.backward()        # Backpropagation
        optimizer.step()       # Update weights

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append((epoch + 1, epoch_train_loss))  # Store epoch number and training loss
    print(f'Epoch {epoch+1} finished, Train Loss: {epoch_train_loss:.4f}')

    # Validation phase
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in valid_loader:  # Use your validation loader
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(valid_loader)
    val_loss_list.append((epoch + 1, epoch_val_loss))  # Store epoch number and validation loss
    print(f'Epoch {epoch+1} finished, Validation Loss: {epoch_val_loss:.4f}')

    # Save the model if it has the best validation loss so far
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)  # Save the model's state dictionary
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")

# Combine and save losses to a CSV file
loss_data = [(epoch, train_loss, val_loss) for (epoch, train_loss), (_, val_loss) in zip(train_loss_list, val_loss_list)]
df = pd.DataFrame(loss_data, columns=['Epoch', 'Train Loss', 'Validation Loss'])
df.to_csv('lossesVGGNet.csv', index=False)

print("Losses saved to 'losses.csv'.")

# Plotting the losses
epochs = [epoch for epoch, _ in train_loss_list]
train_losses = [loss for _, loss in train_loss_list]
val_losses = [loss for _, loss in val_loss_list]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.savefig('loss_plotVGGNet.png')  # Save the plot as a PNG file
plt.show()  # Display the plot
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 finished, Train Loss: 3.7883
# Epoch 1 finished, Validation Loss: 2.7342
# Best model saved with validation loss: 2.7342
# Epoch 2 finished, Train Loss: 2.0267
# Epoch 2 finished, Validation Loss: 1.5696
# Best model saved with validation loss: 1.5696
# Epoch 3 finished, Train Loss: 1.2056
# Epoch 3 finished, Validation Loss: 1.2136
# Best model saved with validation loss: 1.2136
# Epoch 4 finished, Train Loss: 1.0057
# Epoch 4 finished, Validation Loss: 1.0892
# Best model saved with validation loss: 1.0892
# Epoch 5 finished, Train Loss: 0.8649
# Epoch 5 finished, Validation Loss: 1.2407
# Epoch 6 finished, Train Loss: 0.8318
# Epoch 6 finished, Validation Loss: 1.1420
# Epoch 7 finished, Train Loss: 0.7862
# Epoch 7 finished, Validation Loss: 0.8433
# Best model saved with validation loss: 0.8433
# Epoch 8 finished, Train Loss: 0.7977
# Epoch 8 finished, Validation Loss: 0.9820
# Epoch 9 finished, Train Loss: 0.7650
# Epoch 9 finished, Validation Loss: 1.0111
# Epoch 10 finished, Train Loss: 0.8596
# Epoch 10 finished, Validation Loss: 1.2706
# Epoch 11 finished, Train Loss: 0.7712
# Epoch 11 finished, Validation Loss: 1.1192
# Epoch 12 finished, Train Loss: 0.7104
# Epoch 12 finished, Validation Loss: 0.8963
# Epoch 13 finished, Train Loss: 0.6175
# Epoch 13 finished, Validation Loss: 1.0669
# Epoch 14 finished, Train Loss: 0.6313
# Epoch 14 finished, Validation Loss: 1.2587
# Epoch 15 finished, Train Loss: 0.7910
# Epoch 15 finished, Validation Loss: 1.2899
# Epoch 16 finished, Train Loss: 0.7091
# Epoch 16 finished, Validation Loss: 1.0683
# Epoch 17 finished, Train Loss: 0.8402
# Epoch 17 finished, Validation Loss: 0.8932
# Epoch 18 finished, Train Loss: 0.7286
# Epoch 18 finished, Validation Loss: 0.7643
# Best model saved with validation loss: 0.7643
# Epoch 19 finished, Train Loss: 0.6367
# Epoch 19 finished, Validation Loss: 1.1266
# Epoch 20 finished, Train Loss: 0.7077
# Epoch 20 finished, Validation Loss: 0.7436
# Best model saved with validation loss: 0.7436
# Losses saved to 'losses.csv'.

# %% [markdown]
# # **VGGNet16 testing**`

# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score
from tqdm import tqdm

# Function to calculate mAP (mean Average Precision)
def calculate_map(all_labels, all_scores, num_classes):
    mAP_scores = []
    for c in range(num_classes):
        true_labels = (all_labels == c).astype(int)
        pred_scores = all_scores[:, c]  # Scores for class c

        # Handle case where there are no positive samples
        if true_labels.sum() == 0:
            mAP_scores.append(0.0)
            continue

        ap = average_precision_score(true_labels, pred_scores)
        mAP_scores.append(ap)

    mAP = np.mean(mAP_scores)
    return mAP

# Function to evaluate the model
def evaluate_model(model, test_loader, num_classes, model_path=None):
    # Load the best model if the path is provided
    if model_path is not None:
        print(f"Loading the best model from {model_path}")
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)

    model.eval()  # Set model to evaluation mode
    top1_correct = 0
    top5_correct = 0
    total = 0
    all_labels = []
    all_preds = []
    all_scores = []

    with torch.no_grad():
        for images, labels in tqdm(test_loader):
            images = images.to(device)  # Move images to the GPU
            labels = labels.to(device)  # Move labels to the GPU

            outputs = model(images)  # Forward pass

            # Get predicted class probabilities
            pred_scores = torch.softmax(outputs, dim=1)  # Shape: (batch_size, num_classes)

            # Get class predictions
            _, predicted = torch.max(outputs, 1)  # Shape: (batch_size,)

            # Top-1 accuracy
            top1_correct += (predicted == labels).sum().item()
            # Top-5 accuracy
            _, top5_pred = torch.topk(outputs, 5, dim=1)
            top5_correct += (top5_pred == labels.view(-1, 1).expand_as(top5_pred)).sum().item()

            total += labels.size(0)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
            all_scores.append(pred_scores.cpu().numpy())  # Append the scores

    # Calculate accuracies
    top1_accuracy = (top1_correct / total) * 100
    top5_accuracy = (top5_correct / total) * 100

    # Concatenate all predicted scores into a 2D array
    all_scores = np.concatenate(all_scores)  # Shape: (num_samples, num_classes)

    # Calculate mean Average Precision (mAP)
    mAP = calculate_map(np.array(all_labels), all_scores, num_classes)

    print(f'Top-1 Accuracy: {top1_accuracy:.4f}')
    print(f'Top-5 Accuracy: {top5_accuracy:.4f}')
    print(f'mAP: {mAP:.4f}')

    return {
        'Top-1 Accuracy': top1_accuracy,
        'Top-5 Accuracy': top5_accuracy,
        'mAP': mAP,
    }

# Example usage
best_model_path = 'VGGNetbest_model.pth'  # Path where the best model is saved
results = evaluate_model(model, test_loader, num_classes=47, model_path=best_model_path)

# Print evaluation results
for metric, value in results.items():
    print(f'{metric}: {value:.4f}')
# Out:
# Loading the best model from VGGNetbest_model.pth
# <ipython-input-37-efabcc22e77c>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# 100%|██████████| 8/8 [00:01<00:00,  5.21it/s]
# Top-1 Accuracy: 78.0142
# Top-5 Accuracy: 96.4539
# mAP: 0.8626
# Top-1 Accuracy: 78.0142
# Top-5 Accuracy: 96.4539
# mAP: 0.8626

# %% [markdown]
# # **GOogleNet(Inveption)**

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pandas as pd
import matplotlib.pyplot as plt
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Load the pre-trained GoogleNet (Inception v1) model
model = models.googlenet(pretrained=True)  # GoogleNet is available in torchvision

# Freeze all layers except the final fully connected layer
for param in model.parameters():
    param.requires_grad = False  # Freeze all layers
num_classes = 47
model.fc = nn.Linear(model.fc.in_features, num_classes)  # Replace the final layer with 28 classes

# Move the model to the GPU
model = model.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = iAdam(model.parameters(), lr=0.001)  # Adam optimizer

num_epochs = 20
train_loss_list = []  # To store training loss
val_loss_list = []    # To store validation loss
best_val_loss = float('inf')  # Initialize with infinity to track the best validation loss
best_model_path = "GoogleNetbest_model.pth"  # File to store the best model

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()  # Clear gradients
        loss.backward()        # Backpropagation
        optimizer.step()       # Update weights

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append((epoch + 1, epoch_train_loss))  # Store epoch number and training loss
    print(f'Epoch {epoch+1} finished, Train Loss: {epoch_train_loss:.4f}')

    # Validation phase
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in valid_loader:  # Use your validation loader
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(valid_loader)
    val_loss_list.append((epoch + 1, epoch_val_loss))  # Store epoch number and validation loss
    print(f'Epoch {epoch+1} finished, Validation Loss: {epoch_val_loss:.4f}')

    # Save the model if it has the best validation loss so far
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)  # Save the model's state dictionary
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")

# Combine and save losses to a CSV file
loss_data = [(epoch, train_loss, val_loss) for (epoch, train_loss), (_, val_loss) in zip(train_loss_list, val_loss_list)]
df = pd.DataFrame(loss_data, columns=['Epoch', 'Train Loss', 'Validation Loss'])
df.to_csv('lossesGoogleNet.csv', index=False)

print("Losses saved to 'losses.csv'.")

# Plotting the losses
epochs = [epoch for epoch, _ in train_loss_list]
train_losses = [loss for _, loss in train_loss_list]
val_losses = [loss for _, loss in val_loss_list]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.savefig('loss_plot.png')  # Save the plot as a PNG file
plt.show()  # Display the plot
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 finished, Train Loss: 3.8429
# Epoch 1 finished, Validation Loss: 3.8989
# Best model saved with validation loss: 3.8989
# Epoch 2 finished, Train Loss: 3.7683
# Epoch 2 finished, Validation Loss: 3.8110
# Best model saved with validation loss: 3.8110
# Epoch 3 finished, Train Loss: 3.6234
# Epoch 3 finished, Validation Loss: 3.7390
# Best model saved with validation loss: 3.7390
# Epoch 4 finished, Train Loss: 3.5275
# Epoch 4 finished, Validation Loss: 3.6041
# Best model saved with validation loss: 3.6041
# Epoch 5 finished, Train Loss: 3.4078
# Epoch 5 finished, Validation Loss: 3.5435
# Best model saved with validation loss: 3.5435
# Epoch 6 finished, Train Loss: 3.2886
# Epoch 6 finished, Validation Loss: 3.4447
# Best model saved with validation loss: 3.4447
# Epoch 7 finished, Train Loss: 3.1698
# Epoch 7 finished, Validation Loss: 3.3465
# Best model saved with validation loss: 3.3465
# Epoch 8 finished, Train Loss: 3.0233
# Epoch 8 finished, Validation Loss: 3.2354
# Best model saved with validation loss: 3.2354
# Epoch 9 finished, Train Loss: 2.9376
# Epoch 9 finished, Validation Loss: 3.1651
# Best model saved with validation loss: 3.1651
# Epoch 10 finished, Train Loss: 2.7422
# Epoch 10 finished, Validation Loss: 3.0342
# Best model saved with validation loss: 3.0342
# Epoch 11 finished, Train Loss: 2.6601
# Epoch 11 finished, Validation Loss: 2.9336
# Best model saved with validation loss: 2.9336
# Epoch 12 finished, Train Loss: 2.5765
# Epoch 12 finished, Validation Loss: 2.8867
# Best model saved with validation loss: 2.8867
# Epoch 13 finished, Train Loss: 2.4399
# Epoch 13 finished, Validation Loss: 2.8164
# Best model saved with validation loss: 2.8164
# Epoch 14 finished, Train Loss: 2.3735
# Epoch 14 finished, Validation Loss: 2.7734
# Best model saved with validation loss: 2.7734
# Epoch 15 finished, Train Loss: 2.3162
# Epoch 15 finished, Validation Loss: 2.6562
# Best model saved with validation loss: 2.6562
# Epoch 16 finished, Train Loss: 2.2061
# Epoch 16 finished, Validation Loss: 2.6116
# Best model saved with validation loss: 2.6116
# Epoch 17 finished, Train Loss: 2.1068
# Epoch 17 finished, Validation Loss: 2.5488
# Best model saved with validation loss: 2.5488
# Epoch 18 finished, Train Loss: 2.0333
# Epoch 18 finished, Validation Loss: 2.4528
# Best model saved with validation loss: 2.4528
# Epoch 19 finished, Train Loss: 1.9675
# Epoch 19 finished, Validation Loss: 2.4286
# Best model saved with validation loss: 2.4286
# Epoch 20 finished, Train Loss: 1.9411
# Epoch 20 finished, Validation Loss: 2.3747
# Best model saved with validation loss: 2.3747
# Losses saved to 'losses.csv'.

# %% [markdown]
# # **GoogleNet Testing**

# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score
from tqdm import tqdm

# Function to calculate mAP (mean Average Precision)
def calculate_map(all_labels, all_scores, num_classes):
    mAP_scores = []
    for c in range(num_classes):
        true_labels = (all_labels == c).astype(int)
        pred_scores = all_scores[:, c]  # Scores for class c

        # Handle case where there are no positive samples
        if true_labels.sum() == 0:
            mAP_scores.append(0.0)
            continue

        ap = average_precision_score(true_labels, pred_scores)
        mAP_scores.append(ap)

    mAP = np.mean(mAP_scores)
    return mAP

# Function to evaluate the model
def evaluate_model(model, test_loader, num_classes, model_path=None):
    # Load the best model if the path is provided
    if model_path is not None:
        print(f"Loading the best model from {model_path}")
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)

    model.eval()  # Set model to evaluation mode
    top1_correct = 0
    top5_correct = 0
    total = 0
    all_labels = []
    all_preds = []
    all_scores = []

    with torch.no_grad():
        for images, labels in tqdm(test_loader):
            images = images.to(device)  # Move images to the GPU
            labels = labels.to(device)  # Move labels to the GPU

            outputs = model(images)  # Forward pass

            # Get predicted class probabilities
            pred_scores = torch.softmax(outputs, dim=1)  # Shape: (batch_size, num_classes)

            # Get class predictions
            _, predicted = torch.max(outputs, 1)  # Shape: (batch_size,)

            # Top-1 accuracy
            top1_correct += (predicted == labels).sum().item()
            # Top-5 accuracy
            _, top5_pred = torch.topk(outputs, 5, dim=1)
            top5_correct += (top5_pred == labels.view(-1, 1).expand_as(top5_pred)).sum().item()

            total += labels.size(0)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
            all_scores.append(pred_scores.cpu().numpy())  # Append the scores

    # Calculate accuracies
    top1_accuracy = (top1_correct / total) * 100
    top5_accuracy = (top5_correct / total) * 100

    # Concatenate all predicted scores into a 2D array
    all_scores = np.concatenate(all_scores)  # Shape: (num_samples, num_classes)

    # Calculate mean Average Precision (mAP)
    mAP = calculate_map(np.array(all_labels), all_scores, num_classes)

    print(f'Top-1 Accuracy: {top1_accuracy:.4f}')
    print(f'Top-5 Accuracy: {top5_accuracy:.4f}')
    print(f'mAP: {mAP:.4f}')

    return {
        'Top-1 Accuracy': top1_accuracy,
        'Top-5 Accuracy': top5_accuracy,
        'mAP': mAP,
    }

# Example usage
best_model_path = 'GoogleNetbest_model.pth'  # Path where the best model is saved
results = evaluate_model(model, test_loader, num_classes=47, model_path=best_model_path)

# Print evaluation results
for metric, value in results.items():
    print(f'{metric}: {value:.4f}')
# Out:
# <ipython-input-39-c30d61469f7e>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Loading the best model from GoogleNetbest_model.pth
# 100%|██████████| 8/8 [00:01<00:00,  6.98it/s]
# Top-1 Accuracy: 66.6667
# Top-5 Accuracy: 85.8156
# mAP: 0.7001
# Top-1 Accuracy: 66.6667
# Top-5 Accuracy: 85.8156
# mAP: 0.7001

# %% [markdown]
# # **EffiecientNet Training**

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pandas as pd
import matplotlib.pyplot as plt
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pre-trained EfficientNet model (EfficientNet-B0 is used here)
model = models.efficientnet_b0(pretrained=True)  # Use efficientnet_b0 to efficientnet_b7 for different sizes

# Freeze all layers except the final fully connected layer
for param in model.parameters():
    param.requires_grad = False  # Freeze all layers

# Modify the final fully connected layer for 28 output classes
num_classes = 47
model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)  # Replace the classifier

# Move the model to the GPU
model = model.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = iAdam(model.parameters(), lr=0.001)  # Adam optimizer

num_epochs = 20
train_loss_list = []  # To store training loss
val_loss_list = []    # To store validation loss
best_val_loss = float('inf')  # Initialize with infinity to track the best validation loss
best_model_path = "EfficientNetbest_model.pth"  # File to store the best model

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()  # Clear gradients
        loss.backward()        # Backpropagation
        optimizer.step()       # Update weights

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append((epoch + 1, epoch_train_loss))  # Store epoch number and training loss
    print(f'Epoch {epoch+1} finished, Train Loss: {epoch_train_loss:.4f}')

    # Validation phase
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in valid_loader:  # Use your validation loader
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(valid_loader)
    val_loss_list.append((epoch + 1, epoch_val_loss))  # Store epoch number and validation loss
    print(f'Epoch {epoch+1} finished, Validation Loss: {epoch_val_loss:.4f}')

    # Save the model if it has the best validation loss so far
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)  # Save the model's state dictionary
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")

# Combine and save losses to a CSV file
loss_data = [(epoch, train_loss, val_loss) for (epoch, train_loss), (_, val_loss) in zip(train_loss_list, val_loss_list)]
df = pd.DataFrame(loss_data, columns=['Epoch', 'Train Loss', 'Validation Loss'])
df.to_csv('lossesEfficientNet.csv', index=False)

print("Losses saved to 'losses.csv'.")

# Plotting the losses
epochs = [epoch for epoch, _ in train_loss_list]
train_losses = [loss for _, loss in train_loss_list]
val_losses = [loss for _, loss in val_loss_list]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.savefig('loss_plotEnet.png')  # Save the plot as a PNG file
plt.show()  # Display the plot
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 finished, Train Loss: 3.9002
# Epoch 1 finished, Validation Loss: 3.8148
# Best model saved with validation loss: 3.8148
# Epoch 2 finished, Train Loss: 3.7925
# Epoch 2 finished, Validation Loss: 3.7376
# Best model saved with validation loss: 3.7376
# Epoch 3 finished, Train Loss: 3.6361
# Epoch 3 finished, Validation Loss: 3.6592
# Best model saved with validation loss: 3.6592
# Epoch 4 finished, Train Loss: 3.4927
# Epoch 4 finished, Validation Loss: 3.5312
# Best model saved with validation loss: 3.5312
# Epoch 5 finished, Train Loss: 3.3346
# Epoch 5 finished, Validation Loss: 3.3648
# Best model saved with validation loss: 3.3648
# Epoch 6 finished, Train Loss: 3.1754
# Epoch 6 finished, Validation Loss: 3.2655
# Best model saved with validation loss: 3.2655
# Epoch 7 finished, Train Loss: 2.9943
# Epoch 7 finished, Validation Loss: 3.1428
# Best model saved with validation loss: 3.1428
# Epoch 8 finished, Train Loss: 2.8670
# Epoch 8 finished, Validation Loss: 3.0573
# Best model saved with validation loss: 3.0573
# Epoch 9 finished, Train Loss: 2.7147
# Epoch 9 finished, Validation Loss: 2.9101
# Best model saved with validation loss: 2.9101
# Epoch 10 finished, Train Loss: 2.6318
# Epoch 10 finished, Validation Loss: 2.8631
# Best model saved with validation loss: 2.8631
# Epoch 11 finished, Train Loss: 2.4906
# Epoch 11 finished, Validation Loss: 2.7738
# Best model saved with validation loss: 2.7738
# Epoch 12 finished, Train Loss: 2.3747
# Epoch 12 finished, Validation Loss: 2.6574
# Best model saved with validation loss: 2.6574
# Epoch 13 finished, Train Loss: 2.2098
# Epoch 13 finished, Validation Loss: 2.6478
# Best model saved with validation loss: 2.6478
# Epoch 14 finished, Train Loss: 2.0946
# Epoch 14 finished, Validation Loss: 2.4659
# Best model saved with validation loss: 2.4659
# Epoch 15 finished, Train Loss: 2.0232
# Epoch 15 finished, Validation Loss: 2.4573
# Best model saved with validation loss: 2.4573
# Epoch 16 finished, Train Loss: 1.9515
# Epoch 16 finished, Validation Loss: 2.3976
# Best model saved with validation loss: 2.3976
# Epoch 17 finished, Train Loss: 1.8188
# Epoch 17 finished, Validation Loss: 2.3240
# Best model saved with validation loss: 2.3240
# Epoch 18 finished, Train Loss: 1.7945
# Epoch 18 finished, Validation Loss: 2.3008
# Best model saved with validation loss: 2.3008
# Epoch 19 finished, Train Loss: 1.7268
# Epoch 19 finished, Validation Loss: 2.1844
# Best model saved with validation loss: 2.1844
# Epoch 20 finished, Train Loss: 1.6810
# Epoch 20 finished, Validation Loss: 2.2120
# Losses saved to 'losses.csv'.

# %% [markdown]
# # **EffiecientNet Testing**

# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score
from tqdm import tqdm

# Function to calculate mAP (mean Average Precision)
def calculate_map(all_labels, all_scores, num_classes):
    mAP_scores = []
    for c in range(num_classes):
        true_labels = (all_labels == c).astype(int)
        pred_scores = all_scores[:, c]  # Scores for class c

        # Handle case where there are no positive samples
        if true_labels.sum() == 0:
            mAP_scores.append(0.0)
            continue

        ap = average_precision_score(true_labels, pred_scores)
        mAP_scores.append(ap)

    mAP = np.mean(mAP_scores)
    return mAP

# Function to evaluate the model
def evaluate_model(model, test_loader, num_classes, model_path=None):
    # Load the best model if the path is provided
    if model_path is not None:
        print(f"Loading the best model from {model_path}")
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)

    model.eval()  # Set model to evaluation mode
    top1_correct = 0
    top5_correct = 0
    total = 0
    all_labels = []
    all_preds = []
    all_scores = []

    with torch.no_grad():
        for images, labels in tqdm(test_loader):
            images = images.to(device)  # Move images to the GPU
            labels = labels.to(device)  # Move labels to the GPU

            outputs = model(images)  # Forward pass

            # Get predicted class probabilities
            pred_scores = torch.softmax(outputs, dim=1)  # Shape: (batch_size, num_classes)

            # Get class predictions
            _, predicted = torch.max(outputs, 1)  # Shape: (batch_size,)

            # Top-1 accuracy
            top1_correct += (predicted == labels).sum().item()
            # Top-5 accuracy
            _, top5_pred = torch.topk(outputs, 5, dim=1)
            top5_correct += (top5_pred == labels.view(-1, 1).expand_as(top5_pred)).sum().item()

            total += labels.size(0)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
            all_scores.append(pred_scores.cpu().numpy())  # Append the scores

    # Calculate accuracies
    top1_accuracy = (top1_correct / total) * 100
    top5_accuracy = (top5_correct / total) * 100

    # Concatenate all predicted scores into a 2D array
    all_scores = np.concatenate(all_scores)  # Shape: (num_samples, num_classes)

    # Calculate mean Average Precision (mAP)
    mAP = calculate_map(np.array(all_labels), all_scores, num_classes)

    print(f'Top-1 Accuracy: {top1_accuracy:.4f}')
    print(f'Top-5 Accuracy: {top5_accuracy:.4f}')
    print(f'mAP: {mAP:.4f}')

    return {
        'Top-1 Accuracy': top1_accuracy,
        'Top-5 Accuracy': top5_accuracy,
        'mAP': mAP,
    }

# Example usage
best_model_path = 'EfficientNetbest_model.pth'  # Path where the best model is saved
results = evaluate_model(model, test_loader, num_classes=47, model_path=best_model_path)

# Print evaluation results
for metric, value in results.items():
    print(f'{metric}: {value:.4f}')
# Out:
# <ipython-input-41-24909babde40>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Loading the best model from EfficientNetbest_model.pth
# 100%|██████████| 8/8 [00:01<00:00,  6.96it/s]
# Top-1 Accuracy: 68.0851
# Top-5 Accuracy: 91.4894
# mAP: 0.7086
# Top-1 Accuracy: 68.0851
# Top-5 Accuracy: 91.4894
# mAP: 0.7086

# %% [markdown]
# # **DenseNet Training**

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pandas as pd
import matplotlib.pyplot as plt
import os

# Check if CUDA is available and set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pre-trained DenseNet model (DenseNet121 is used here)
model = models.densenet121(pretrained=True)  # You can also use densenet169, densenet201

# Freeze all layers except the final fully connected layer
for param in model.parameters():
    param.requires_grad = False  # Freeze all layers

# Modify the final fully connected layer for 28 output classes
num_classes = 47
model.classifier = nn.Linear(model.classifier.in_features, num_classes)  # Replace the classifier

# Move the model to the GPU
model = model.to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Suitable for multi-class classification
optimizer = iAdam(model.parameters(), lr=0.001)  # Adam optimizer

num_epochs = 20
train_loss_list = []  # To store training loss
val_loss_list = []    # To store validation loss
best_val_loss = float('inf')  # Initialize with infinity to track the best validation loss
best_model_path = "DenseNetbest_model.pth"  # File to store the best model

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        # Move images and labels to GPU
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()  # Clear gradients
        loss.backward()        # Backpropagation
        optimizer.step()       # Update weights

        running_train_loss += loss.item()

    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append((epoch + 1, epoch_train_loss))  # Store epoch number and training loss
    print(f'Epoch {epoch+1} finished, Train Loss: {epoch_train_loss:.4f}')

    # Validation phase
    model.eval()
    running_val_loss = 0.0

    with torch.no_grad():
        for images, labels in valid_loader:  # Use your validation loader
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

    epoch_val_loss = running_val_loss / len(valid_loader)
    val_loss_list.append((epoch + 1, epoch_val_loss))  # Store epoch number and validation loss
    print(f'Epoch {epoch+1} finished, Validation Loss: {epoch_val_loss:.4f}')

    # Save the model if it has the best validation loss so far
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), best_model_path)  # Save the model's state dictionary
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")

# Combine and save losses to a CSV file
loss_data = [(epoch, train_loss, val_loss) for (epoch, train_loss), (_, val_loss) in zip(train_loss_list, val_loss_list)]
df = pd.DataFrame(loss_data, columns=['Epoch', 'Train Loss', 'Validation Loss'])
df.to_csv('lossesDenseNet.csv', index=False)

print("Losses saved to 'losses.csv'.")

# Plotting the losses
epochs = [epoch for epoch, _ in train_loss_list]
train_losses = [loss for _, loss in train_loss_list]
val_losses = [loss for _, loss in val_loss_list]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.savefig('loss_plotDenseNet.png')  # Save the plot as a PNG file
plt.show()  # Display the plot
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 finished, Train Loss: 4.0238
# Epoch 1 finished, Validation Loss: 3.9105
# Best model saved with validation loss: 3.9105
# Epoch 2 finished, Train Loss: 3.7704
# Epoch 2 finished, Validation Loss: 3.7790
# Best model saved with validation loss: 3.7790
# Epoch 3 finished, Train Loss: 3.6000
# Epoch 3 finished, Validation Loss: 3.6307
# Best model saved with validation loss: 3.6307
# Epoch 4 finished, Train Loss: 3.4255
# Epoch 4 finished, Validation Loss: 3.4762
# Best model saved with validation loss: 3.4762
# Epoch 5 finished, Train Loss: 3.1899
# Epoch 5 finished, Validation Loss: 3.2608
# Best model saved with validation loss: 3.2608
# Epoch 6 finished, Train Loss: 3.0123
# Epoch 6 finished, Validation Loss: 3.1122
# Best model saved with validation loss: 3.1122
# Epoch 7 finished, Train Loss: 2.8087
# Epoch 7 finished, Validation Loss: 2.9539
# Best model saved with validation loss: 2.9539
# Epoch 8 finished, Train Loss: 2.5938
# Epoch 8 finished, Validation Loss: 2.7524
# Best model saved with validation loss: 2.7524
# Epoch 9 finished, Train Loss: 2.4253
# Epoch 9 finished, Validation Loss: 2.5956
# Best model saved with validation loss: 2.5956
# Epoch 10 finished, Train Loss: 2.1868
# Epoch 10 finished, Validation Loss: 2.4180
# Best model saved with validation loss: 2.4180
# Epoch 11 finished, Train Loss: 2.0184
# Epoch 11 finished, Validation Loss: 2.2359
# Best model saved with validation loss: 2.2359
# Epoch 12 finished, Train Loss: 1.8626
# Epoch 12 finished, Validation Loss: 2.1476
# Best model saved with validation loss: 2.1476
# Epoch 13 finished, Train Loss: 1.6924
# Epoch 13 finished, Validation Loss: 2.0240
# Best model saved with validation loss: 2.0240
# Epoch 14 finished, Train Loss: 1.6138
# Epoch 14 finished, Validation Loss: 1.9903
# Best model saved with validation loss: 1.9903
# Epoch 15 finished, Train Loss: 1.4434
# Epoch 15 finished, Validation Loss: 1.8247
# Best model saved with validation loss: 1.8247
# Epoch 16 finished, Train Loss: 1.3607
# Epoch 16 finished, Validation Loss: 1.7400
# Best model saved with validation loss: 1.7400
# Epoch 17 finished, Train Loss: 1.2356
# Epoch 17 finished, Validation Loss: 1.6714
# Best model saved with validation loss: 1.6714
# Epoch 18 finished, Train Loss: 1.1697
# Epoch 18 finished, Validation Loss: 1.5944
# Best model saved with validation loss: 1.5944
# Epoch 19 finished, Train Loss: 1.0999
# Epoch 19 finished, Validation Loss: 1.5347
# Best model saved with validation loss: 1.5347
# Epoch 20 finished, Train Loss: 0.9966
# Epoch 20 finished, Validation Loss: 1.4909
# Best model saved with validation loss: 1.4909
# Losses saved to 'losses.csv'.

# %% [markdown]
# # **DenseNet Testing**

# %%
import torch
import numpy as np
from sklearn.metrics import average_precision_score
from tqdm import tqdm

# Function to calculate mAP (mean Average Precision)
def calculate_map(all_labels, all_scores, num_classes):
    mAP_scores = []
    for c in range(num_classes):
        true_labels = (all_labels == c).astype(int)
        pred_scores = all_scores[:, c]  # Scores for class c

        # Handle case where there are no positive samples
        if true_labels.sum() == 0:
            mAP_scores.append(0.0)
            continue

        ap = average_precision_score(true_labels, pred_scores)
        mAP_scores.append(ap)

    mAP = np.mean(mAP_scores)
    return mAP

# Function to evaluate the model
def evaluate_model(model, test_loader, num_classes, model_path=None):
    # Load the best model if the path is provided
    if model_path is not None:
        print(f"Loading the best model from {model_path}")
        model.load_state_dict(torch.load(model_path))
        model = model.to(device)

    model.eval()  # Set model to evaluation mode
    top1_correct = 0
    top5_correct = 0
    total = 0
    all_labels = []
    all_preds = []
    all_scores = []

    with torch.no_grad():
        for images, labels in tqdm(test_loader):
            images = images.to(device)  # Move images to the GPU
            labels = labels.to(device)  # Move labels to the GPU

            outputs = model(images)  # Forward pass

            # Get predicted class probabilities
            pred_scores = torch.softmax(outputs, dim=1)  # Shape: (batch_size, num_classes)

            # Get class predictions
            _, predicted = torch.max(outputs, 1)  # Shape: (batch_size,)

            # Top-1 accuracy
            top1_correct += (predicted == labels).sum().item()
            # Top-5 accuracy
            _, top5_pred = torch.topk(outputs, 5, dim=1)
            top5_correct += (top5_pred == labels.view(-1, 1).expand_as(top5_pred)).sum().item()

            total += labels.size(0)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
            all_scores.append(pred_scores.cpu().numpy())  # Append the scores

    # Calculate accuracies
    top1_accuracy = (top1_correct / total) * 100
    top5_accuracy = (top5_correct / total) * 100

    # Concatenate all predicted scores into a 2D array
    all_scores = np.concatenate(all_scores)  # Shape: (num_samples, num_classes)

    # Calculate mean Average Precision (mAP)
    mAP = calculate_map(np.array(all_labels), all_scores, num_classes)

    print(f'Top-1 Accuracy: {top1_accuracy:.4f}')
    print(f'Top-5 Accuracy: {top5_accuracy:.4f}')
    print(f'mAP: {mAP:.4f}')

    return {
        'Top-1 Accuracy': top1_accuracy,
        'Top-5 Accuracy': top5_accuracy,
        'mAP': mAP,
    }

# Example usage
best_model_path = 'DenseNetbest_model.pth'  # Path where the best model is saved
results = evaluate_model(model, test_loader, num_classes=47, model_path=best_model_path)

# Print evaluation results
for metric, value in results.items():
    print(f'{metric}: {value:.4f}')
# Out:
# <ipython-input-43-b972b31304bf>:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Loading the best model from DenseNetbest_model.pth
# 100%|██████████| 8/8 [00:01<00:00,  6.60it/s]
# Top-1 Accuracy: 70.9220
# Top-5 Accuracy: 94.3262
# mAP: 0.7742
# Top-1 Accuracy: 70.9220
# Top-5 Accuracy: 94.3262
# mAP: 0.7742
